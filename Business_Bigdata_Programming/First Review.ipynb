# %%
import nltk

from nltk import word_tokenize

with open('C:/Users/user/result_t.txt', 'r', encoding = 'utf-8') as f:
    
    lines = f.readlines()
    
    f.close()

# %%
firstReview = lines[0]

tokens = nltk.word_tokenize(firstReview)

tags = nltk.pos_tag(tokens)

print('Tokens of first review: ')

print(tokens)

print('POS tags of first review: ')

print(tags)
# Out:
# Tokens of first review:
# ...
